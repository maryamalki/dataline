# %%
import pandas as pd

# %%
df = pd.read_excel("~/Downloads/Hydrogen Production.xlsx", sheet_name=None, header=6)

# %%
# Loop through each sheet
# Loop through headers 0 -> N until a header row is found (column names not null)
# Loop through the columns 0 -> N until a column that is not all null is found
# Consider that subset to be the dataset

# %%
df["Aggregated data"]
# Out:
#      Unnamed: 0         Country        Process type Subprocess type  \
# 0           NaN         Austria          By-product    Chlor-alkali
# 1           NaN         Austria          By-product        Ethylene
# 2           NaN         Austria           Reforming             NaN
# 3           NaN         Austria           Reforming             NaN
# 4           NaN         Austria           Reforming             NaN
# ..          ...             ...                 ...             ...
# 200         NaN     Switzerland  Water electrolysis             NaN
# 201         NaN     Switzerland  Water electrolysis             NaN
# 202         NaN     Switzerland  Water electrolysis             NaN
# 203         NaN  United Kingdom  Water electrolysis             NaN
# 204         NaN  United Kingdom  Water electrolysis             NaN
#
#                                End-use  Number of plants  \
# 0                      Other chemicals                 1
# ...
